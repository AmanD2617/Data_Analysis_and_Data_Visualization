# %% [markdown]
# # Task 1: Importing Necessary Libraries

# %%
import numpy as np 
import pandas as pd   
import seaborn as sns  
import matplotlib.pyplot as plt    
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Reading the CSV file

# %%
a = pd.read_csv("BankChurners.csv")

# %%
df = pd.DataFrame(a)

# %% [markdown]
# # Task 2: Displaying sample of Data

# %%
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df.tail(5)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %% [markdown]
# # Task 3: Checking shape of Data

# %%
df.shape
# Out:
# (10127, 21)

# %% [markdown]
# # Task 4: Checking percentage of missing values in each column of data

# %%
a = df.isnull().any(axis=1).value_counts()
# There is no null value in data
print(a)
# Out:
# False    10127
# dtype: int64

# %%
b = 10127
percentage = (a/b)*100
print(percentage)
# The percentage of not null values = 100%
# Out:
# False    100.0
# dtype: float64

# %% [markdown]
# # Task 5: Checking for the Duplicate Rows

# %%
df.duplicated().any(axis=0)
# Out:
# False

# %% [markdown]
# # Task 6: Checking the distribution of the Customer_Age column

# %%
sns.histplot(df.Customer_Age , kde = True)
plt.show()

# %% [markdown]
# #  Checking the basic statistics like mean, median, and standard deviation of  the age column

# %%
df.describe().Customer_Age
# Out:
# count    10127.000000
# mean        46.325960
# std          8.016814
# min         26.000000
# 25%         41.000000
# 50%         46.000000
# 75%         52.000000
# max         73.000000
# Name: Customer_Age, dtype: float64

# %%
df.median().Customer_Age
# Out:
# 46.0

# %% [markdown]
# # Task 7: Plot 2 box plots and 2 pie chart of the parameter of your own choice and write your intuition about it

# %%
sns.boxplot(x = "Income_Category" , y = "Credit_Limit" ,data = df)
plt.show()
print("This is the Box PLot for Income_Category and Credit_Limit which is here representing that ,which income category person is having the how much credit limit")
print("There are following cases : ")
print("Case 1: Less than 40K : There Credit_Limit is Less Than 5K $ " , "Outliers : More Than 5K and Less Than 20K ")
print("Case 2: 40k-60k $ : There Credit_Limit is More Than 5K$ Less Than 10K $", "Outliers : More Than 10K and Less Than 25K ")
print("Case 3: 60k-80k $ : There Credit_Limit is 15K $", "Outliers : More Than 30K and Less Than 35K ")
print("Case 4: 80k-120k $ : There Credit_Limit is 25K $", "Outliers : No Outliers")
print("Case 5: 120K+ $ : There Credit_Limit is 35K $ ", "Outliers : No Outliers ")
print("Case 6: Unknown : There Credit_Limit is More Than 10K and Less Than 15K $", "Outliers : More Than 25K and Less Than 35K ")
# Out:
# This is the Box PLot for Income_Category and Credit_Limit which is here representing that ,which income category person is having the how much credit limit
# There are following cases :
# Case 1: Less than 40K : There Credit_Limit is Less Than 5K $  Outliers : More Than 5K and Less Than 20K
# Case 2: 40k-60k $ : There Credit_Limit is More Than 5K$ Less Than 10K $ Outliers : More Than 10K and Less Than 25K
# Case 3: 60k-80k $ : There Credit_Limit is 15K $ Outliers : More Than 30K and Less Than 35K
# Case 4: 80k-120k $ : There Credit_Limit is 25K $ Outliers : No Outliers
# Case 5: 120K+ $ : There Credit_Limit is 35K $  Outliers : No Outliers
# Case 6: Unknown : There Credit_Limit is More Than 10K and Less Than 15K $ Outliers : More Than 25K and Less Than 35K

# %%
sns.boxplot(x = "Income_Category" , y = "Avg_Utilization_Ratio" ,data = df)
plt.show()
print("This is the box plot for Income_Category and Avg_Utilization_Ratio that represents which income category person is having the how much credit limit" )
print("These are the following cases: ")
print("Case 1: Less than 40K : There Credit_Limit is Less Than 0.8 ", "Outliers : No Outliers")
print("Case 2: 40k-60k $ : There Credit_Limit is More Than 0.0 Less Than 0.6", " Outliers : No Outliers")
print("Case 3: 60k-80k $ : There Credit_Limit is  More Than 0.0 Less Than 0.4",  "Outliers : More Than 0.6 and till 1.0 ")
print("Case 4: 80k-120k $ : There Credit_Limit is more than 0.0 less than 0.2", "Outliers :  More Than 0.4  and till 1.0 ")
print("Case 5: 120K+ $ : There Credit_Limit is more than 0.0 less than 0.2 ", "Outliers :  More Than 0.2 less than 1.0 ")
print("Case 6: Unknown : There Credit_Limit is More Than 10K and Less Than 0.4", "Outliers : More Than 0.8 and till 1.0 ")
# Out:
# This is the box plot for Income_Category and Avg_Utilization_Ratio that represents which income category person is having the how much credit limit
# These are the following cases:
# Case 1: Less than 40K : There Credit_Limit is Less Than 0.8  Outliers : No Outliers
# Case 2: 40k-60k $ : There Credit_Limit is More Than 0.0 Less Than 0.6  Outliers : No Outliers
# Case 3: 60k-80k $ : There Credit_Limit is  More Than 0.0 Less Than 0.4 Outliers : More Than 0.6 and till 1.0
# Case 4: 80k-120k $ : There Credit_Limit is more than 0.0 less than 0.2 Outliers :  More Than 0.4  and till 1.0
# Case 5: 120K+ $ : There Credit_Limit is more than 0.0 less than 0.2  Outliers :  More Than 0.2 less than 1.0
# Case 6: Unknown : There Credit_Limit is More Than 10K and Less Than 0.4 Outliers : More Than 0.8 and till 1.0

# %%
x = df["Gender"].unique().tolist()
y = df["Gender"].value_counts()
colors = ["#1f77b4", "#ff7f0e"]
plt.figure(figsize=(5,8))
plt.pie( y, labels = x,autopct = "%1.1f%%", colors=colors,startangle=140)
print(y)
print("This is Pie Chart of the Percentage of Total Male and Female Customers of Happy Bank")
print("There are total : " , " Females : 5358 " , " Males : 4769 " )
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64
# This is Pie Chart of the Percentage of Total Male and Female Customers of Happy Bank
# There are total :   Females : 5358   Males : 4769

# %%
x = df["Card_Category"].unique().tolist()
y = df["Card_Category"].value_counts()
plt.figure(figsize=(8,8))
plt.pie( y, labels = x,autopct = "%1.1f%%",startangle=140)
print("This is Pie Chart of the Percentage of Different categories of Happy Bank Card Holders")
print("There are 4 Categories of Cards " )
print(y)
# Out:
# This is Pie Chart of the Percentage of Different categories of Happy Bank Card Holders
# There are 4 Categories of Cards
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %% [markdown]
# # Task 8: Plot a Box-plot of Total_Revolving_Bal and Card_Category by characterizing with Attrition_Flag

# %%
sns.boxplot(x = "Total_Revolving_Bal" , y = "Card_Category" ,data = df,hue ="Attrition_Flag")
plt.show()

# %% [markdown]
# # Task 9: Plot a percentage segment bar graph between Education_Level and Attrition_Flag of the customers

# %%
data = df.groupby('Education_Level')[['Attrition_Flag']].apply(lambda x: x.apply(pd.value_counts)).unstack().fillna(0)
data_percent = data.apply(lambda x: x / x.sum() * 100, axis=1)
data_percent.plot(kind='bar', stacked=True)
plt.xlabel('Education_Level')
plt.ylabel('Percentage')
plt.title('Stacked Bar Graph between Education_Level and Attrition_Flag of the customers')
plt.legend()
plt.show()

# %% [markdown]
# # Task 10:	Plot a percentage segment bar graph between Income_Category and Attrition_Flag of the customers

# %%
data = df.groupby('Income_Category')[['Attrition_Flag']].apply(lambda x: x.apply(pd.value_counts)).unstack().fillna(0)
data_percent = data.apply(lambda x: x / x.sum() * 100, axis=1)
data_percent.plot(kind='bar', stacked=True)
plt.xlabel('Income_Category')
plt.ylabel('Percentage')
plt.title('Stacked Bar Graph between Income_Category and Attrition_Flag of the customers')
plt.legend()
plt.show()

# %% [markdown]
# # Task 11: Drop CLIENTNUM column

# %%
df.drop(["CLIENTNUM"] , axis = 1)
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# # Make a sub data frame which consists of all the numerical columns(i.e.int64,float64) along with the Attrition_Flag column.

# %%
df1 = df.drop(["Gender","Education_Level","Income_Category","Card_Category","CLIENTNUM"],axis = 1)

# %%
df1
# Out:
#           Attrition_Flag  Customer_Age  Dependent_count Marital_Status  \
# 0      Existing Customer            45                3        Married
# 1      Existing Customer            49                5         Single
# 2      Existing Customer            51                3        Married
# 3      Existing Customer            40                4        Unknown
# 4      Existing Customer            40                3        Married
# ...                  ...           ...              ...            ...
# 10122  Existing Customer            50                2         Single
# 10123  Attrited Customer            41                2       Divorced
# 10124  Attrited Customer            44                1        Married
# 10125  Attrited Customer            30                2        Unknown
# 10126  Attrited Customer            43                2        Married
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %% [markdown]
# # Plot a clear heatmap to view the correlation using seaborn

# %%
sns.heatmap(df.corr(), annot=True,fmt="0.1f")
plt.show()

# %% [markdown]
# # Task 12: 12.	Plot a boxplot for the Credit_Limit column and check if it contains any outlier or not

# %%
sns.boxplot(x = "Credit_Limit" ,data = df)
plt.show()
print("Yes ,there is an outlier in Credit_Limit which is from More Than 20K Till 35k ")
# Out:
# Yes ,there is an outlier in Credit_Limit which is from More Than 20K Till 35k

# %% [markdown]
# # Task 13: 13.	Map the Attrition_Flag values to 0 and 1(i.e. Existing Customer=0 and Attrited Customer=1. Standardize the columns

# %%
df.replace(to_replace = ("Existing Customer","Attrited Customer") , value = (0,1))
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383               0            45      M                3
# 1      818770008               0            49      F                5
# 2      713982108               0            51      M                3
# 3      769911858               0            40      F                4
# 4      709106358               0            40      M                3
# ...          ...             ...           ...    ...              ...
# 10122  772366833               0            50      M                2
# 10123  710638233               1            41      M                2
# 10124  716506083               1            44      F                1
# 10125  717406983               1            30      M                2
# 10126  714337233               1            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.std()
# Out:
# CLIENTNUM                   3.690378e+07
# Customer_Age                8.016814e+00
# Dependent_count             1.298908e+00
# Months_on_book              7.986416e+00
# Total_Relationship_Count    1.554408e+00
# Months_Inactive_12_mon      1.010622e+00
# Contacts_Count_12_mon       1.106225e+00
# Credit_Limit                9.088777e+03
# Total_Revolving_Bal         8.149873e+02
# Avg_Open_To_Buy             9.090685e+03
# Total_Amt_Chng_Q4_Q1        2.192068e-01
# Total_Trans_Amt             3.397129e+03
# Total_Trans_Ct              2.347257e+01
# Total_Ct_Chng_Q4_Q1         2.380861e-01
# Avg_Utilization_Ratio       2.756915e-01
# dtype: float64
